# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
#One row represents the daily performance of one content page for one client on one report date. I will use the fact_content_daily_performance table from the FlyRank internship warehouse. I will analyze a mid-panel month (for example, 2026-03) to avoid using the final month for development.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
"""Features: - gsc_impressions - gsc_clicks - gsc_avg_position - ga4_sessions - scroll_events
Label / Proxy: - Declining content performance
Context: - report_date - client_hash_id - content_hash_id
Excluded: - Any label-derived field because it would cause data leakage and make the evaluation unrealistic."""
# Out:
# 'Features: - gsc_impressions - gsc_clicks - gsc_avg_position - ga4_sessions - scroll_events\nLabel / Proxy: - Declining content performance \nContext: - report_date - client_hash_id - content_hash_id \nExcluded: - Any label-derived field because it would cause data leakage and make the evaluation unrealistic.'

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
from datasets import load_dataset
from google.colab import userdata

HF_TOKEN = userdata.get("HF_TOKEN")

dataset = load_dataset(
    "FlyRank/internship-warehouse",
    "fact_content_daily_performance",
    split="train",
    token=HF_TOKEN
)

print(dataset)
sample = dataset.select(range(1000)).to_pandas()

print(sample.shape)

sample.head()
sample[["report_date","client_hash_id","content_hash_id"]].head()
print(sample["report_date"].min())
print(sample["report_date"].max())
print(sample["gsc_data_available"].sum())
print(sample["ga4_data_available"].sum())
# Out:
# ...
# Loading dataset shards:   0%|          | 0/39 [00:00<?, ?it/s]
# Dataset({
#     features: ['report_date', 'client_hash_id', 'content_hash_id', 'client_has_gsc', 'client_has_ga4', 'gsc_data_available', 'ga4_data_available', 'gsc_impressions', 'gsc_clicks', 'gsc_sum_position', 'gsc_avg_position', 'ga4_pageviews', 'ga4_sessions', 'ga4_users', 'ga4_engaged_sessions', 'ga4_total_engagement_sec', 'sessions_organic', 'sessions_direct', 'sessions_referral', 'sessions_social', 'sessions_paid', 'sessions_ai', 'ai_chatgpt', 'ai_perplexity', 'ai_gemini', 'ai_copilot', 'ai_claude', 'ai_meta', 'ai_other', 'scroll_events'],
#     num_rows: 78835655
# })
# (1000, 30)
# 2025-01-27
# 2025-01-30
# 1000
# 0

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
"""This dataset shows observed performance only.

It cannot explain why performance changed.

Some rows may have missing GSC or GA4 data."""
# Out:
# 'This dataset shows observed performance only.\n\nIt cannot explain why performance changed.\n\nSome rows may have missing GSC or GA4 data.'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
